# %% [markdown]
# ## Counting Words, Part 1: TF/IDF ##
#
# *Based of tutorials by [Matthew Lavin](https://programminghistorian.org/en/lessons/analyzing-documents-with-tfidf) and [Kavita Ganesan](https://kavita-ganesan.com/tfidftransformer-tfidfvectorizer-usage-differences/#.XZVlcOdKhSw)*
#
# Topic modelling can be a powerful technique for identifying the themes that recur in a corpus. But in many cases, just counting words can also tell you a lot.
#
# To begin, we're going to explore a method called Term Frequency - Inverse Document Frequency (tf-idf). Tf-idf comes up a lot in text analysis projects because it’s both a corpus exploration method and a pre-processing step for many other text-mining measures and models.
#
# The procedure was introduced in a 1972 paper by Karen Spärck Jones under the name “term specificity,” and the basic idea is this:
#
# Instead of representing a term in a document by its raw frequency (its number of occurrences) or its relative frequency (the term count divided by the document length), each term is *weighted* by dividing the term frequency by the number of documents in the corpus containing the word.
#
# The overall effect of this weighting scheme is to avoid a common problem when conducting text analysis: the most frequently used words in a document are often the most frequently used words in all of the documents. We encountered this very problem in our topic model of the CCP Corpus.
#
# By contrast, terms with the highest tf-idf scores are the terms in a document that are distinctively frequent in a document, when that document is compared other documents. When you sort by tf-idf score, these distinctive terms rise to the top.

# %% [markdown]
# ### An Analogy ###
#
# If this explanation doesn’t quite resonate, a brief analogy might help.
#
# Say you've decided leave campus to get dinner on Buford Highway. Since leaving campus takes a lot of effort (and also, crucially, access to a car), the food better be worth it! That means you'll need to balance two competing goals:
#
# 1) The food has to be really tasty; and also, crucially:
# 2) If you're going to go all the way out to Buford Highway, it better be something that you can't also get in Emory Village. Otherwise, why go to all the trouble of getting there?!
#
# Or, to give an example involving actual food: you don't want to go all the way out to Buford Highway to get pizza. Even if the pizza on Buford Highway is pretty tasty, you can get pizza anywhere in town. How can you find out what is distintively tasty on Buford Highway?
#
# If you looked up the Yelp reviews for the all restaurants on Buford highway and sorted by score, you would get an answer to the question of what's the tastiest. But it still won't help solve the problem of what's *distintively tasty* on Buford Highway--like hot pot, for example, which is something that you can't get in Emory Village.
#
# So you need a way to tell the difference between what's tasty and what's distinctively tasty. To do so, you need to distinguish between four categories of food. Food that, on Buford Highway, is:
#
# - both tasty and distinctive (e.g. hot pot)
# - tasty but not distinctive (e.g. pizza)
# - distinctive but not tasty (e.g. tacos-- tho I'm open to disagreement here)
# - neither tasty nor distinctive (e.g. Taco Bell).

# %% [markdown]
# These categories are what TF/IDF helps you measure. Term frequencies can be assessed according to the same criteria. A term might be:
#
# - Frequently used in a language like English, and especially frequent (or infrequent) in one document
# - Frequently used in a language like English, but used to a typical degree in one document
# - Infrequently used in a language like English, but distinctly frequent (or infrequent) in one document
# - Infrequently used in a language like English, and used at to a typical degree in one document

# %% [markdown]
# It's the words that are especially frequent in one document that are most interesting to us, and the ones that TF/IDF helps us identify. To see how, let's turn back to the CCP example.

# %% [markdown]
# ### TF-IDF: How to do it ###
#
# As always, to start, we need to perform some pre-procesing of our corpus to get it into the format that TF/IDF requires.
#
# For TF/IDF, this format is much simpler than what was required for our topic model. Here, we just need to create a list in which each doc is a single string.
#
# **Note**: This logic: iterate through all the documents in a corpus, and do something to each text file one at a time, is the same logic we used to write the iter_docs function that we used in our last class. You'll get very familiar with writing document and text pre-processing code like this by the end of the semester.

# %%
import os

base_dir = "./2019-09-ccp-corpus-0.3/ccprecords/" # NOTE: Your path may be different!!!

all_docs = [] # our list which will store the text of each doc; empty for now

docs = os.listdir(base_dir) # get a list of all the files in the directory

for doc in docs: # iterate through the docs
    if not doc.startswith('.'): # get only the .txt files
        with open(base_dir + doc, "r", encoding="utf-8") as file: # force unicode conversion to keep PCs happy
            text = file.read() # read in the file as a single text string
            all_docs.append(text) # append it to the all_docs list

# lastly, just take a look at the first list item to be sure it worked
all_docs[0]
# Out:
# 'THE JERSEY CONVENTION .\n\nWe have received a call for a New Citizens\' State Convention in New Jersey, to meet at New Brunswick, June 3, 1873. Despite the fact that this New Citizens\' convention , is to be held at New Brunswick in New Jersey, we find ourselves altogether unable to appreciate the necessity for it. WE are to be pitied, possibly, but we must confess to the fact that we find ourselves unable to appreciate four-fifths of the political conventions held by the colored men of the country. Without an exception, scarcely, they are simply axe-grinding assemblies. Managed chiefly by men who are unfit to lead, and too ambitious to follow, they but tend to compromise our interests with the nation. Called ostensibly to advance that interest, according to our way of thinking, they greatly retard it. And yet much depends upon the aim in view. Like unto what class of the American people is it purposed to mould the American Negro. That he must receive some mould is plain. A slave in the past, an alien and a stranger, Providence found him as the ancient Etrurian found his clay, and the word of the hour, is to give him mounding. What shall it be? The third and fourth class politicians, into whose hands he really seems to have fallen, say, that he shall receive the mould of a politician; and to that end they are conventionising him. But should he receive this mould? From the very depth of our souls, we say, God forbid. The Irish of New York have such mould. The nation cannot stand two such. It groans beneath the burden of one. Another, will prove its death. Nor would it change our thoughts, one iota, were these same politicians to say, their purpose was to make the Negro, a Statesman, and not simply, a corner politician however much we doubt their ability to do so. Aside from the fact that such a think is impossible at least for the present generation, we argue, that even if it were possible, our best interest would dictate that we receive another, than even the mould fo Statesmen. Statesmen are born, not made; and they are born in the proportion that Providence\'s desires them, and man needs them. Rarae Aves sunt.\n\nBut say these gentlemen, if we don\'t look after the inters of our people, they will be endangered; and will be finally lost. Not a bit of it. IF they themselves believe it, they show a want of judgement, if they don\'t\' believe it, they show a want of conscience; and he who wants either judgment or conscience, is not fit to lead. But it is not true. As a people we do not need their guidance; and we hesitate not to say, that if even our interests are lost, they will be lost through their ignorance, and unreasonable ambition. Insisting as we do that another, than a political mould be given our people, and recognizing the force of these endless conventions in that direction, we oppose the greater majority of them.\n\nTime ordains the "survival of the fittest," and greatly desiring the survival of our race, not as a race but as American citizens; are we asked the mould we would have them received. WE reply in brief; we would have them be molded as the honest and happy yeomanry of the country. Wise in the knowledge of their rights, and courageous to maintain. A people whose liberty and enfranchisement are as necessary to the preservation of good government, as they are just to themselves. In short, a people to save whom no contemptible demagogue, black or white, will have the temerity to say, If I don\'t look after their interest, they will be lost.'

# %% [markdown]
# You can calculate TF/IDF manually using addition and division. But we're going to use scikit-learn's TF/IDF modules because they have built-in tokenization.
#
# Note that we're now encountering a *third* library that does tokenization for us. The takeaway in this case is that after interating through your docs and getting your text into whatever format is required, as in the code cell above, the next step us (usually) to tokenize it.

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

#instantiate CountVectorizer()
cv=CountVectorizer(stop_words='english') # using stopwords this time
 
# this steps returns word counts for the words in your docs 
word_count_vector=cv.fit_transform(all_docs)

# check shape
word_count_vector.shape
# Out:
# (147, 24930)

# %% [markdown]
# That last line tells us that we have 147 rows, one for each document in the corpus, and 24,930 columns, one for each word (minus single character words, which the tokenizer excludes, as well as the default stopwords, which we've indicated with the `stop_words='english'` parameter above).
#
# We can also look at the whole vocabulary like this:

# %%
cv.vocabulary_
# Out:
# {'jersey': 12967,
#  'convention': 5702,
#  'received': 18547,
#  'new': 15557,
#  'citizens': 4668,
#  'state': 21273,
#  'meet': 14673,
#  'brunswick': 3731,
#  'june': 13101,
#  '1873': 307,
#  'despite': 6960,
#  'fact': 9219,
#  'held': 11228,
#  'altogether': 1699,
#  'unable': 23119,
#  'appreciate': 2014,
#  'necessity': 15469,
#  'pitied': 17090,
#  'possibly': 17392,
#  'confess': 5341,
#  'fifths': 9535,
#  'political': 17286,
#  'conventions': 5706,
#  'colored': 4970,
#  'men': 14712,
#  'country': 5929,
#  'exception': 8933,
#  'scarcely': 19922,
#  'simply': 20628,
#  'axe': 2593,
#  'grinding': 10726,
#  'assemblies': 2282,
#  'managed': 14263,
#  'chiefly': 4541,
#  'unfit': 23323,
#  'lead': 13506,
#  'ambitious': 1723,
#  'follow': 9744,
#  'tend': 22261,
#  'compromise': 5225,
#  'interests': 12597,
#  'nation': 15401,
#  'called': 3973,
#  'ostensibly': 16175,
#  'advance': 1348,
#  'according': 1122,
#  'way': 24257,
#  'thinking': 22422,
#  'greatly': 10665,
#  'retard': 19236,
#  'depends': 6819,
#  'aim': 1547,
#  'view': 23926,
#  'like': 13753,
#  'unto': 23573,
#  'class': 4724,
#  'american': 1746,
#  'people': 16726,
#  'purposed': 18169,
#  'mould': 15222,
#  'negro': 15506,
#  'receive': 18546,
#  'plain': 17113,
#  'slave': 20745,
#  'past': 16562,
#  'alien': 1609,
#  'stranger': 21486,
#  'providence': 18046,
#  'ancient': 1794,
#  'etrurian': 8804,
#  'clay': 4736,
#  'word': 24694,
#  'hour': 11557,
#  'mounding': 15231,
#  'shall': 20357,
#  'fourth': 9933,
#  'politicians': 17289,
#  'hands': 10950,
#  'really': 18487,
#  'fallen': 9270,
#  'say': 19901,
#  'politician': 17288,
#  'end': 8410,
#  'conventionising': 5704,
#  'depth': 6865,
#  'souls': 20990,
#  'god': 10496,
#  'forbid': 9787,
#  'irish': 12781,
#  'york': 24888,
#  'stand': 21232,
#  'groans': 10737,
#  'beneath': 2998,
#  'burden': 3815,
#  'prove': 18036,
#  'death': 6442,
#  'change': 4389,
#  'thoughts': 22459,
#  'iota': 12773,
#  'purpose': 18168,
#  'make': 14209,
#  'statesman': 21282,
#  'corner': 5817,
#  'doubt': 7717,
#  'ability': 978,
#  'aside': 2241,
#  'think': 22419,
#  'impossible': 11950,
#  'present': 17606,
#  'generation': 10310,
#  'argue': 2103,
#  'possible': 17391,
#  'best': 3088,
#  'dictate': 7105,
#  'fo': 9726,
#  'statesmen': 21286,
#  'born': 3420,
#  'proportion': 17951,
#  'desires': 6935,
#  'man': 14258,
#  'needs': 15488,
#  'rarae': 18408,
#  'aves': 2560,
#  'sunt': 21810,
#  'gentlemen': 10334,
#  'don': 7670,
#  'look': 13950,
#  'inters': 12641,
#  'endangered': 8412,
#  'finally': 9565,
#  'lost': 13984,
#  'bit': 3190,
#  'believe': 2956,
#  'want': 24150,
#  'judgement': 13079,
#  'conscience': 5451,
#  'wants': 24155,
#  'judgment': 13082,
#  'fit': 9616,
#  'true': 22981,
#  'need': 15477,
#  'guidance': 10812,
#  'hesitate': 11306,
#  'ignorance': 11754,
#  'unreasonable': 23498,
#  'ambition': 1721,
#  'insisting': 12470,
#  'given': 10425,
#  'recognizing': 18587,
#  'force': 9791,
#  'endless': 8428,
#  'direction': 7198,
#  'oppose': 16059,
#  'greater': 10661,
#  'majority': 14206,
#  'time': 22569,
#  'ordains': 16102,
#  'survival': 21937,
#  'fittest': 9622,
#  'desiring': 6936,
#  'race': 18300,
#  'asked': 2243,
#  'reply': 19009,
#  'brief': 3623,
#  'molded': 15070,
#  'honest': 11474,
#  'happy': 10979,
#  'yeomanry': 24868,
#  'wise': 24597,
#  'knowledge': 13283,
#  'rights': 19418,
#  'courageous': 5944,
#  'maintain': 14193,
#  'liberty': 13709,
#  'enfranchisement': 8469,
#  'necessary': 15465,
#  'preservation': 17614,
#  'good': 10519,
#  'government': 10561,
#  'just': 13119,
#  'short': 20499,
#  'save': 19885,
#  'contemptible': 5599,
#  'demagogue': 6712,
#  'black': 3197,
#  'white': 24420,
#  'temerity': 22227,
#  'proceedings': 17777,
#  'conference': 5336,
#  'florida': 9699,
#  'gainesville': 10170,
#  'february': 9417,
#  '1884': 318,
#  'address': 1240,
#  'delivered': 6693,
#  'president': 17623,
#  'james': 12895,
#  'dean': 6436,
#  'll': 13861,
#  'executive': 8985,
#  'committee': 5083,
#  'washington': 24204,
#  'morning': 15165,
#  'session': 20290,
#  'pursuant': 18179,
#  'representing': 19033,
#  'voters': 24057,
#  'assembled': 2280,
#  'day': 6412,
#  'roper': 19566,
#  'hall': 10898,
#  'city': 4673,
#  '10': 37,
#  'clock': 4802,
#  'rev': 19272,
#  'augustus': 2490,
#  'waters': 24239,
#  'chairman': 4353,
#  'arrangements': 2153,
#  'appointed': 2001,
#  'order': 16105,
#  'general': 10303,
#  'josiah': 13041,
#  'walls': 24134,
#  'alachua': 1567,
#  'county': 5935,
#  'moved': 15249,
#  'hon': 11470,
#  'willis': 24535,
#  'menard': 14718,
#  'monroe': 15109,
#  'temporary': 22246,
#  'agreed': 1515,
#  'mr': 15264,
#  'talking': 22112,
#  'chair': 4351,
#  'eloquent': 8230,
#  'major': 14204,
#  'bryant': 3748,
#  'hillsborough': 11357,
#  'messrs': 14793,
#  'gibbs': 10386,
#  'duval': 7930,
#  'lightbourn': 13741,
#  'gadsden': 10157,
#  'act': 1191,
#  'secretaries': 20104,
#  'announced': 1851,
#  'business': 3881,
#  'roll': 19541,
#  'lewey': 13678,
#  'secretary': 20105,
#  'proceeded': 17775,
#  'following': 9748,
#  'counties': 5924,
#  'answered': 1877,
#  'gen': 10296,
#  'chestnut': 4525,
#  'parker': 16475,
#  'clinton': 4796,
#  'william': 24522,
#  'trapp': 22845,
#  'shivery': 20472,
#  'edward': 8087,
#  'taylor': 22179,
#  'joseph': 13035,
#  'fisher': 9609,
#  'seventy': 20309,
#  'marion': 14366,
#  'chandler': 4385,
#  'bonner': 3384,
#  'mccant': 14537,
#  'mason': 14433,
#  'wilkerson': 24505,
#  'cummings': 6223,
#  'kennedy': 13179,
#  'david': 6398,
#  'hopkins': 11504,
#  'levy': 13677,
#  'john': 13001,
#  'murrell': 15320,
#  'thomas': 22440,
#  'mcknight': 14588,
#  'isaac': 12820,
#  'carrin': 4161,
#  'ransom': 18391,
#  'edwards': 8088,
#  'wm': 24642,
#  'artrell': 2200,
#  'rome': 19551,
#  'dupont': 7907,
#  'butler': 3894,
#  'jefferson': 12930,
#  'long': 13938,
#  'eli': 8189,
#  'dilworth': 7165,
#  'proe': 17815,
#  'ter': 22295,
#  'erwin': 8728,
#  'patton': 16608,
#  'madison': 14142,
#  'alexander': 1593,
#  'osgood': 16170,
#  'orange': 16087,
#  'boger': 3338,
#  'colman': 4951,
#  'volusia': 24048,
#  'wiley': 24497,
#  'grimes': 10722,
#  'lee': 13559,
#  'sampson': 19800,
#  'brown': 3715,
#  'ballou': 2659,
#  'green': 10676,
#  'griffin': 10712,
#  'ferguson': 9469,
#  'escambia': 8731,
#  'witherspoon': 24622,
#  'davidson': 6399,
#  'sumter': 21792,
#  'tilman': 22562,
#  'henry': 11261,
#  'brooks': 3698,
#  'tanner': 22132,
#  'mike': 14845,
#  'gudsden': 10806,
#  'swannee': 21975,
#  'leon': 13625,
#  'wallace': 24128,
#  'santa': 19840,
#  'rosa': 19569,
#  'crocket': 6109,
#  'anthony': 1896,
#  'hawthorn': 11123,
#  'columbia': 4980,
#  'frederick': 9995,
#  'martin': 14408,
#  'nassau': 15391,
#  'samuel': 19803,
#  'petty': 16923,
#  'robinson': 19506,
#  'port': 17345,
#  'king': 13232,
#  'bradford': 3510,
#  'thompson': 22444,
#  'pollard': 17295,
#  'permanent': 16789,
#  'organization': 16129,
#  'esq': 8746,
#  'second': 20095,
#  'nomination': 15664,
#  'appropriate': 2038,
#  'speech': 21088,
#  'unanimously': 23135,
#  'elected': 8161,
#  'escort': 8736,
#  'newly': 15575,
#  'seat': 20080,
#  'taking': 22096,
#  'eloquently': 8231,
#  'appended': 1978,
#  'motion': 15209,
#  'vice': 23899,
#  'murrill': 15321,
#  'assistant': 2317,
#  'sergeant': 20252,
#  'arms': 2137,
#  'submitted': 21643,
#  'resolution': 19141,
#  'resolved': 19145,
#  'published': 18094,
#  'news': 15579,
#  'suggesting': 21750,
#  'adopted': 1324,
#  'assemble': 2279,
#  'amendment': 1740,
#  'strike': 21535,
#  'including': 12071,
#  'autocrat': 2522,
#  'insert': 12453,
#  'lieu': 13726,
#  'thereof': 22397,
#  'favor': 9376,
#  'independent': 12152,
#  'governor': 10565,
#  'existing': 9033,
#  'circumstances': 4653,
#  'warrant': 24185,
#  'accepted': 1079,
#  'amended': 1738,
#  'embodied': 8278,
#  'platform': 17154,
#  'quod': 18286,
#  'vide': 23922,
#  'consisting': 5502,
#  'conferee': 5335,
#  'represented': 19032,
#  'select': 20171,
#  'riley': 19424,
#  'fred': 9993,
#  '30': 504,
#  'recess': 18555,
#  'reassemble': 18507,
#  'court': 5949,
#  'house': 11561,
#  'tendered': 22266,
#  'sheriff': 20430,
#  'evening': 8847,
#  'reassembled': 18508,
#  'geo': 10341,
#  'report': 19011,
#  'selection': 20175,
#  'considered': 5491,
#  'matters': 14491,
#  'referred': 18694,
#  'beg': 2909,
#  'leave': 13541,
#  'follows': 9749,
#  'changed': 4390,
#  'danville': 6354,
#  'massacre': 14440,
#  'result': 19213,
#  'democratic': 6735,
#  'plan': 17127,
#  'defeat': 6575,
#  'movement': 15250,
#  'south': 21000,
#  'solidify': 20930,
#  'presidential': 17624,
#  'campaign': 4004,
#  'secure': 20120,
#  'electoral': 8168,
#  'vote': 24054,
#  'candidate': 4030,
#  'presidency': 17622,
#  'feared': 9396,
#  'division': 7590,
#  'old': 15979,
#  'parties': 16523,
#  'independents': 12154,
#  'weakness': 24271,
#  'render': 18931,
#  'future': 10152,
#  'hopeless': 11500,
#  'large': 13418,
#  'ineffective': 12236,
#  'election': 8163,
#  'district': 7549,
#  'resolve': 19144,
#  'determine': 7012,
#  'course': 5947,
#  'action': 1194,
#  'unite': 23393,
#  'uniting': 23397,
#  'effect': 8099,
#  'office': 15944,
#  'redress': 18664,
#  'evils': 8870,
#  'grievances': 10705,
#  'subjected': 21623,
#  'increased': 12109,
#  'facilities': 9215,
#  'common': 5093,
#  'school': 19962,
#  'education': 8075,
#  'highest': 11341,
#  'branches': 3529,
#  'able': 981,
#  'reduce': 18667,
#  'high': 11339,
#  'rate': 18420,
#  'illiteracy': 11780,
#  'census': 4311,
#  'shows': 20529,
#  'exist': 9030,
#  'fair': 9247,
#  'representation': 19028,
#  'juries': 13107,
#  'courts': 5958,
#  'justices': 13122,
#  'peace': 16635,
#  'cast': 4199,
#  'votes': 24058,
#  'freely': 10011,
#  'fairly': 9253,
#  'counted': 5910,
#  'better': 3111,
#  'registration': 18769,
#  'commissioners': 5073,
#  'power': 17432,
#  'injustice': 12397,
#  'recognition': 18581,
#  'offices': 15951,
#  'governments': 10563,
#  'enjoy': 8515,
#  'privileges': 17754,
#  'accorded': 1121,
#  'public': 18087,
#  'places': 17109,
#  'railroads': 18333,
#  'steamers': 21329,
#  'pay': 16621,
#  'fare': 9313,
#  'law': 13472,
#  'enacted': 8372,
#  'restoring': 19199,
#  'right': 19409,
#  'suffrage': 21742,
#  'disfranchised': 7366,
#  'alleged': 1628,
#  'offenses': 15936,
#  'tried': 22927,
#  'disadvantages': 7222,
#  'accord': 1118,
#  'local': 13886,
#  'whites': 24428,
#  'deal': 6429,
#  'justly': 13130,
#  'chances': 4384,
#  'enable': 8367,
#  'citizenship': 4669,
#  'bear': 2856,
#  'share': 20375,
#  'burdens': 3817,
#  'responsibilities': 19181,
#  'adopt': 1322,
#  'recommend': 18593,
#  'printed': 17727,
#  'pamphlet': 16409,
#  'form': 9853,
#  'gentleman': 10331,
#  'duty': 7929,
#  'policy': 17279,
#  'suggested': 21749,
#  'roger': 19533,
#  'hadley': 10875,
#  'eaq': 7963,
#  'suwannee': 21967,
#  'livingston': 13857,
#  'jackson': 12880,
#  'campbell': 4007,
#  'holmes': 11454,
#  'signed': 20587,
#  'resolutions': 19142,
#  'offered': 15939,
#  'hearby': 11163,
#  'invite': 12754,
#  'various': 23781,
#  'states': 21281,
#  'immigrate': 11840,
#  'quantities': 18223,
#  'unoccupied': 23459,
#  'lands': 13386,
#  'furnishing': 10132,
#  'opportunities': 16057,
#  'homes': 11463,
#  'express': 9124,
#  'appreciation': 2018,
#  'regard': 18749,
#  'national': 15403,
#  'administration': 1294,
#  'head': 11142,
#  'stands': 21237,
#  'chester': 4522,
#  'arthur': 2185,
#  'life': 13730,
#  'friend': 10042,
#  'thank': 22350,
#  'sherman': 20432,
#  'ohio': 15972,
#  'recently': 18552,
#  'taken': 22092,
#  'senate': 20195,
#  'defense': 6593,
#  'virginia': 23987,
#  'mississippi': 14999,
#  'members': 14693,
#  'vacancy': 23709,
#  'caused': 4260,
#  'failure': 9241,
#  'send': 20200,
#  'delegates': 6666,
#  'louisville': 14004,
#  'september': 20237,
#  '1883': 317,
#  'habitual': 10862,
#  'use': 23668,
#  'intoxicating': 12676,
#  'liquors': 13815,
#  'promotes': 17901,
#  'habits': 10861,
#  'idleness': 11739,
#  'extravagance': 9183,
#  'shortest': 20504,
#  'road': 19480,
#  'beggary': 2916,
#  'degradation': 6635,
#  'temperance': 22231,
#  'handmaid': 10949,
#  'thrift': 22477,
#  'economy': 8032,
#  'leading': 13511,
#  'attainment': 2409,
#  'wealth': 24274,
#  'enjoyment': 8518,
#  'ease': 7985,
#  'happiness': 10978,
#  'unmindful': 23440,
#  'drink': 7820,
#  'habit': 10856,
#  'prevails': 17671,
#  'alarming': 1573,
#  'extent': 9152,
#  'ruinous': 19653,
#  'tendencies': 22263,
#  'inimical': 12373,
#  'society': 20880,
#  'destructive': 6988,
#  'welfare': 24326,
#  'recommends': 18598,
#  'powerful': 17433,
#  'levers': 13669,
#  'raised': 18346,
#  'higher': 11340,
#  'plane': 17128,
#  'civilization': 4680,
#  'refinement': 18699,
#  'independence': 12150,
#  'invokes': 12761,
#  'ministers': 14910,
#  'teachers': 22187,
#  'heads': 11149,
#  'families': 9292,
#  'mothers': 15208,
#  'wives': 24637,
#  'daughters': 6392,
#  'husbands': 11671,
#  'brothers': 3707,
#  'sons': 20956,
#  'advancement': 1350,
#  'tender': 22265,
#  'thanks': 22355,
#  'lewy': 13682,
#  'efficient': 8111,
#  'manner': 14300,
#  'discharged': 7272,
#  'duties': 7927,
#  'adjourned': 1268,
#  'sine': 20639,
#  'die': 7119,
#  'met': 14794,
#  'adjournment': 1271,
#  'organized': 16132,
#  'electing': 8162,
#  'corresponding': 5850,
#  'considering': 5492,
#  'connected': 5425,
#  'work': 24701,
#  'constitution': 5542,
#  'desirable': 6931,
#  'machinery': 14121,
#  'cumbersome': 6220,
#  'expensive': 9077,
#  'accordance': 1119,
#  'principles': 17724,
#  'popular': 17335,
#  'respectfully': 19167,
#  'organizing': 16136,
#  'subject': 21622,
#  'practical': 17444,
#  'application': 1993,
#  'doctrine': 7615,
#  'equal': 8667,
#  'regardless': 18752,
#  'color': 4968,
#  'distribution': 7548,
#  'federal': 9420,
#  'patronage': 16601,
#  'faithfully': 9261,
#  'carried': 4157,
#  'col': 4908,
#  'wicker': 24464,
#  'collector': 4937,
#  'customs': 6282,
#  'key': 13198,
#  'west': 24346,
#  'ledwith': 13558,
#  'postmaster': 17398,
#  'jacksonville': 12881,
#  'howell': 11572,
#  'fernandina': 9472,
#  'officers': 15950,
#  'fidelity': 9521,
#  'great': 10660,
#  'friendship': 10047,
#  'commend': 5046,
#  'bold': 3349,
#  'faithful': 9260,
#  'organ': 16123,
#  'medium': 14664,
#  'sentiment': 20224,
#  'cordial': 5797,
#  'support': 21875,
#  'sections': 20116,
#  'fellow': 9447,
#  'grave': 10645,
#  'concern': 5261,
#  'body': 3335,
#  'politic': 17285,
#  'commonwealth': 5099,
#  'framers': 9952,
#  'organic': 16125,
#  'foresaw': 9817,
#  'ripe': 19441,
#  'experience': 9078,
#  'affairs': 1410,
#  'assemblages': 2278,
#  'discuss': 7336,
#  'set': 20293,
#  'forth': 9883,
#  'measures': 14637,
#  'courses': 5948,
#  'improvement': 11978,
#  'condition': 5311,
#  'united': 23394,
#  'ninth': 15635,
#  'tenth': 22291,
#  'declaration': 6514,
#  'declare': 6517,
#  'laws': 13484,
#  'abridging': 1025,
#  'freedom': 10006,
#  'press': 17630,
#  'peaceably': 16637,
#  'consult': 5560,
#  'petition': 16910,
#  'abuse': 1057,
#  'privilege': 17752,
#  'land': 13373,
#  'important': 11936,
#  'wisdom': 24596,
#  'cool': 5754,
#  'prevail': 17667,
#  'council': 5893,
#  'careful': 4114,
#  'thought': 22456,
#  'deliberation': 6675,
#  'characterize': 4417,
#  'reflect': 18703,
#  'credit': 6048,
#  'calmly': 3983,
#  'carefully': 4115,
#  'completely': 5177,
#  'manly': 14296,
#  'needed': 15478,
#  'standpoint': 21236,
#  'prudent': 18075,
#  'lovers': 14016,
#  'justice': 13121,
#  'play': 17165,
#  'prosperity': 17998,
#  'guide': 10813,
#  'channel': 4393,
#  'deliberations': 6676,
#  'sets': 20295,
#  'things': 22418,
#  'ievances': 11749,
#  'views': 23929,
#  'let': 13647,
#  'attention': 2429,
#  'injuries': 12393,
#  'inflicted': 12309,
#  'imposition': 11946,
#  'oppressive': 16072,
#  'cause': 4259,
#  'arise': 2113,
#  'enforce': 8462,
#  'salutary': 19785,
#  'complete': 5175,
#  'protection': 18011,
#  'promote': 17897,
#  'personal': 16860,
#  'security': 20127,
#  'certain': 4332,
#  'benefit': 3011,
#  'mankind': 14292,
#  'lie': 13722,
#  'constitute': 5538,
#  'fostering': 9912,
#  'spring': 21166,
#  'fundamental': 10115,
#  'leads': 13512,
#  'formation': 9858,
#  'civil': 4676,
#  'free': 10000,
#  'comprehended': 5215,
#  'property': 17937,
#  'religion': 18856,
#  'vital': 24012,
#  'parts': 16534,
#  'sub': 21615,
#  'structure': 21567,
#  'institutions': 12517,
#  'injury': 12396,
#  'prejudice': 17560,
#  'grievance': 10704,
#  'worthy': 24742,
#  'consider': 5483,
#  'separately': 20231,
#  'discover': 7310,
#  'consist': 5496,
#  'material': 14470,
#  'comprise': 5222,
#  'industrial': 12230,
#  'financial': 9568,
#  'operations': 16045,
#  'kind': 13218,
#  'employed': 8340,
#  'acquisition': 1183,
#  'real': 18477,
#  'protect': 18008,
#  'sole': 20912,
#  'possession': 17384,
#  'external': 9160,
#  'world': 24718,
#  'exclusion': 8959,
#  'person': 16856,
#  'chief': 4539,
#  'ends': 8439,
#  'score': 19995,
#  'complaint': 5172,
#  'amounts': 1770,
#  'opinion': 16051,
#  'prevailing': 17669,
#  'favors': 9385,
#  'cases': 4190,
#  'place': 17104,
#  'pale': 16383,
#  'feeling': 9433,
#  'friends': 10046,
#  'cities': 4664,
#  'conspires': 5523,
#  'times': 22573,
#  'prevent': 17674,
#  'purchasing': 18144,
#  'lots': 13987,
#  'particular': 16519,
#  'locality': 13888,
#  'trust': 22997,
#  'honestly': 11475,
#  'spirit': 21120,
#  'caste': 4200,
#  'vanish': 23764,
#  'away': 2585,
#  'relative': 18832,
#  'pertaining': 16874,
#  'require': 19088,
#  'individual': 12200,
#  'rule': 19655,
#  'determining': 7016,
#  'importance': 11935,
#  'citizen': 4666,
#  'superior': 21832,
#  'quantity': 18224,
#  'capital': 4076,
#  'controls': 5684,
#  'annual': 1860,
#  'income': 12074,
#  'carries': 4160,
#  'forcibly': 9795,
#  'suggests': 21754,
#  'bounden': 3451,
#  'homeless': 11461,
#  'posterity': 17396,
#  'viz': 24021,
#  'begin': 2919,
#  'continue': 5635,
#  'exertions': 9003,
#  'flagging': 9636,
#  'energy': 8453,
#  'till': 22550,
#  'acquired': 1179,
#  'home': 11460,
#  '11': 58,
#  'comfortable': 5013,
#  'enterprises': 8597,
#  'joint': 13014,
#  'stock': 21411,
#  'companies': 5119,
#  'mercantile': 14743,
#  'christopher': 4603,
#  'commission': 5070,
#  'merchants': 14750,
#  'hill': 11351,
#  'palatka': 16380,
#  'women': 24662,
#  'saving': 19888,
#  'successful': 21704,
#  'horticulturist': 11528,
#  'names': 15368,
#  'familiar': 9287,
#  'reading': 18468,
#  'moves': 15254,
#  'speak': 21052,
#  'volumes': 24039,
#  'elevation': 8184,
#  'desired': 6934,
#  'noble': 15644,
#  'examples': 8913,
#  'accompanying': 1109,
#  'incidents': 12051,
#  'prestige': 17641,
#  'means': 14627,
#  'demonstrate': 6744,
#  'clearly': 4755,
#  'capabilities': 4065,
#  'increase': 12108,
#  'sorry': 20983,
#  'known': 13284,
#  'squatters': 21194,
#  'homestead': 11464,
#  'entries': 8633,
#  'lived': 13842,
#  'required': 19089,
#  'years': 24860,
#  'final': 9562,
#  'proof': 17924,
#  'entry': 8635,
#  'continuous': 5640,
#  'residence': 19117,
#  'thereon': 22398,
#  'obtain': 15866,
#  'clear': 4750,
#  'title': 22608,
#  'patent': 16574,
#  'instead': 12501,
#  'doing': 7633,
#  'remained': 18872,
#  'complying': 5199,
#  'reverted': 19300,
#  'settled': 20298,
#  'shadow': 20337,
#  'eye': 9198,
#  'trespassers': 22906,
#  'shelter': 20420,
#  'lay': 13490,
#  'deplorable': 6825,
#  'thing': 22417,
#  'immediate': 11833,
#  'effective': 8102,
#  'returning': 19267,
#  'respective': 19169,
#  'special': 21061,
#  'bring': 3644,
#  'matter': 14489,
#  'notice': 15720,
#  'negligent': 15500,
#  'insist': 12468,
#  'immediately': 11834,
#  'employ': 8339,
#  'attorneys': 2439,
#  'examine': 8907,
#  'titles': 22610,
#  'steps': 21354,
#  'sure': 21898,
#  'foundations': 9919,
#  'situated': 20687,
#  'afford': 1442,
#  'pleasure': 17185,
#  'earth': 7982,
#  'travel': 22848,
#  'touching': 22718,
#  '12': 71,
#  'township': 22738,
#  'birth': 3179,
#  'assist': 2315,
#  'needy': 15489,
#  'brethren': 3596,
#  'securing': 20125,
#  'claims': 4696,
#  'soil': 20894,
#  'live': 13841,
#  'basis': 2793,
#  'christian': 4594,
#  'moral': 15149,
#  'lessons': 13644,
#  'constantly': 5529,
#  'delineated': 6685,
#  'instilled': 12505,
#  'hearts': 11182,
#  'properly': 17935,
#  'disseminated': 7495,
#  'stamps': 21231,
#  'impress': 11958,
#  'human': 11602,
#  'conduct': 5321,
#  'sphere': 21108,
#  'fireside': 9595,
#  'breast': 3570,
#  'legislator': 13592,
#  ...}

# %% [markdown]
# The numbers above are the indices for each feature, not the word counts.
#
# But we can sort the vocabulary like this:

# %%
sum_words = word_count_vector.sum(axis=0) # sum_words is a vector that contains
                                            # the sum of each word occurrence in all 
                                            # texts in the corpus. In other words, 
                                            # we are adding the elements for each column of
                                            # the word_count_vector matrix

# then sort the list of tuples that contain the word and their occurrence in the corpus.
words_freq = [(word, sum_words[0, idx]) for word, idx in cv.vocabulary_.items()]

words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)

# display the top 10
words_freq[:10]
# Out:
# [('convention', 5296),
#  ('colored', 4217),
#  ('committee', 4183),
#  ('people', 3990),
#  ('state', 3830),
#  ('mr', 3767),
#  ('shall', 3069),
#  ('men', 2481),
#  ('resolved', 2321),
#  ('president', 2043)]

# %% [markdown]
# We can already see some words that don't seem too distinctive: "convention" and "colored," for example. It's not surprising that those are the most frequently occurring words since the corpus is about the colored conventions.
#
# So now let's calculate the IDF values so that we can balance them out.

# %%
import pandas as pd # this will help us keep track of our data; 
# we'll talk about pandas and dataframes in more detail on Tuedsay

# Call tfidf_transformer.fit on the word count vector we computed earlier.
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(word_count_vector)

# print idf values
df_idf = pd.DataFrame(tfidf_transformer.idf_, index=cv.get_feature_names(),columns=["idf_weights"])
 
# sort ascending
df_idf.sort_values(by=['idf_weights'])
# Out:
#              idf_weights
# convention      1.034368
# people          1.034368
# state           1.041385
# colored         1.062738
# men             1.099372
# ...                  ...
# imaginative     5.304065
# imagined        5.304065
# imagining       5.304065
# imbibe          5.304065
# ægis            5.304065
#
# [24930 rows x 1 columns]

# %% [markdown]
# In the table above, the words at the top are those that appear in the most number of documents, across all of the corpus; and the words at the bottom are those that appear in the least number of documents.

# %% [markdown]
# But what are these numbers that we're looking at?
#
# The most direct formula would be **N/df<sub>i</sub>**, where N represents the total number of documents in the corpus, and df is the number of documents in which the term appears.
#
# However, many implementations of tf-idf, including scikit-learn, which we are using, normalize the results with additional operations.
#
# In tf-idf, normalization is generally used in two ways, and for two reasons: first, to prevent bias in term frequency from terms in shorter or longer documents; and second, as above, to calculate each term’s idf value.

# %% [markdown]
# Scikit-learn’s implementation of tf-idf represents N as **N+1**, calculates the natural logarithm of **(N+1)/df<sub>i</sub>**, and then adds **1** to the final result.
#
# ![tf-idf](http://lklein.lmc.gatech.edu/wp-content/uploads/2019/10/Screen-Shot-2019-10-02-at-11.52.31-PM.png)

# %% [markdown]
# **Important note!** This is only one way to calculate TF-IDF. There are many, many versions. The number itself isn't important. It's the ranking that the number enables that's most interesting to us. Because one you have the IDF values, you can now compute the tf-idf scores for any document or set of documents.
#
# So now let’s compute tf-idf scores for the documents in our corpus.

# %%
# tf-idf scores
tf_idf_vector=tfidf_transformer.transform(word_count_vector)

# %% [markdown]
# And let’s print the tf-idf values of the first document to see if it makes sense.
#
# What we are doing below is, placing the tf-idf scores from the first document into a pandas data frame and sorting it in descending order of scores.

# %%
feature_names = cv.get_feature_names()
 
#get tfidf vector for first document
first_document_vector=tf_idf_vector[0]
 
#print the scores for the first doc
df = pd.DataFrame(first_document_vector.T.todense(), index=feature_names, columns=["tfidf"])
df.sort_values(by=["tfidf"],ascending=False).head(10)
# Out:
#                tfidf
# mould       0.584650
# survival    0.163179
# don         0.147537
# brunswick   0.146163
# say         0.142156
# new         0.140073
# jersey      0.120605
# lost        0.120424
# receive     0.110154
# politician  0.109566

# %% [markdown]
# You can actually do the TF-IDF calculation in one step, so now we're going to do the very same thing again using scikit-learn's all-in-one TF-IDF vectorizer.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 
 
# settings that you use for count vectorizer will go here
tfidf_vectorizer=TfidfVectorizer(stop_words='english', use_idf=True)
 
# just send in all your docs here
tfidf_vectorizer_vectors=tfidf_vectorizer.fit_transform(all_docs)

# %%
# as above, get the first vector out (for the first document) to see what it looks like
first_vector_tfidfvectorizer=tfidf_vectorizer_vectors[0]
 
# place tf-idf values in a pandas data frame
df = pd.DataFrame(first_vector_tfidfvectorizer.T.todense(), index=tfidf_vectorizer.get_feature_names(), columns=["tfidf"])
df.sort_values(by=["tfidf"],ascending=False).head(10)
# Out:
#                tfidf
# mould       0.584650
# survival    0.163179
# don         0.147537
# brunswick   0.146163
# say         0.142156
# new         0.140073
# jersey      0.120605
# lost        0.120424
# receive     0.110154
# politician  0.109566

# %% [markdown]
# Finally, let's print our TF-IDF vectors and store them to csv files so we can explore the scores using Excel.

# %%
base_dir = "./2019-09-ccp-corpus-0.3/ccprecords/"

# make a directory to store them in
# os.mkdir("./tf_idf_output")

docs = os.listdir(base_dir)

csvs = []

for doc in docs:
    if not doc.startswith('.'): # get only the .txt files
        csv = doc.replace(".txt",".csv")
        csvs.append(csv)

# convert sparse matrix to array
tfidf_vectors_as_array = tfidf_vectorizer_vectors.toarray() # LK: explain this. 

# loop each item in tfidf_vectors_as_array, 
for counter, doc in enumerate(tfidf_vectors_as_array): # note enumerate. useful! 
    # construct a dataframe
    tf_idf_tuples = list(zip(tfidf_vectorizer.get_feature_names(), doc))
    one_doc_as_df = pd.DataFrame.from_records(tf_idf_tuples, columns=['term', 'score']).sort_values(by='score', ascending=False).reset_index(drop=True)

    print("\n Doc " + str(counter) + " top 5 terms: ")
    print(one_doc_as_df.head())
    
    # output to a csv using the enumerated value for the filename
    # one_doc_as_df.to_csv(csvs[counter])
# Out:
#  Doc 0 top 5 terms:
#         term     score
# 0      mould  0.584650
# 1   survival  0.163179
# 2        don  0.147537
# 3  brunswick  0.146163
# 4        say  0.142156
#
#  Doc 1 top 5 terms:
#          term     score
# 0     florida  0.296138
# 1      county  0.278028
# 2  conference  0.242936
# 3       state  0.204529
# 4      public  0.198948
#
#  Doc 2 top 5 terms:
#        term     score
# 0     haven  0.249525
# 1  resolved  0.237184
# 2     beman  0.201325
# 3  hartford  0.182991
# 4      1855  0.169296
#
#  Doc 3 top 5 terms:
#      term     score
# 0      00  0.308812
# 1    iowa  0.308045
# 2  moines  0.281295
# 3     des  0.259792
# 4    alex  0.249078
#
#  Doc 4 top 5 terms:
#          term     score
# 0    nebraska  0.422682
# 1  convention  0.342318
# 2     orleans  0.243819
# 3  williamson  0.194031
# 4    douglass  0.182945
#
#  Doc 5 top 5 terms:
#            term     score
# 0            mr  0.362022
# 1         state  0.210594
# 2        league  0.191628
# 3    convention  0.178186
# 4  pennsylvania  0.170460
#
#  Doc 6 top 5 terms:
#        term     score
# 0  arkansas  0.295884
# 1      grey  0.257735
# 2     state  0.171277
# 3      1865  0.161579
# 4   andrews  0.154641
#
#  Doc 7 top 5 terms:
#         term     score
# 0      niles  0.420281
# 1   portland  0.237781
# 2      siggs  0.205189
# 3  committee  0.150890
# 4   resolved  0.148339
#
#  Doc 8 top 5 terms:
#         term     score
# 0   reciting  0.358662
# 1    colored  0.330662
# 2  murdering  0.327123
# 3   arkansas  0.261215
# 4       hung  0.261215
#
#  Doc 9 top 5 terms:
#          term     score
# 0     detroit  0.214129
# 1  convention  0.191161
# 2     lambert  0.179271
# 3       state  0.173483
# 4    resolved  0.161855
#
#  Doc 10 top 5 terms:
#           term     score
# 0        shall  0.296333
# 1  association  0.267320
# 2         cook  0.168902
# 3   convention  0.162355
# 4     douglass  0.153392
#
#  Doc 11 top 5 terms:
#          term     score
# 0          mr  0.224828
# 1   committee  0.221297
# 2       newby  0.199676
# 3  convention  0.186146
# 4    townsend  0.186131
#
#  Doc 12 top 5 terms:
#        term     score
# 0     state  0.250650
# 1   norfolk  0.248469
# 2  virginia  0.229516
# 3     court  0.228256
# 4   colored  0.182438
#
#  Doc 13 top 5 terms:
#           term     score
# 0      protest  0.353012
# 1   convention  0.334818
# 2         york  0.261599
# 3          new  0.203706
# 4  schenectady  0.187340
#
#  Doc 14 top 5 terms:
#            term     score
# 0        league  0.576823
# 1       bustill  0.229765
# 2            mr  0.226428
# 3  philadelphia  0.224294
# 4    harrisburg  0.186162
#
#  Doc 15 top 5 terms:
#         term     score
# 0  residents  0.417923
# 1     mining  0.334266
# 2   reported  0.262576
# 3        san  0.234826
# 4     county  0.230730
#
#  Doc 16 top 5 terms:
#         term     score
# 0  nashville  0.257835
# 1      loyal  0.228396
# 2  tennessee  0.200198
# 3   resolved  0.186844
# 4      messr  0.183994
#
#  Doc 17 top 5 terms:
#            term     score
# 0     mulattoes  0.215853
# 1       indiana  0.212987
# 2  indianapolis  0.191771
# 3       persons  0.180195
# 4       negroes  0.173312
#
#  Doc 18 top 5 terms:
#           term     score
# 0        texas  0.356600
# 1  association  0.344651
# 2       dallas  0.332166
# 3    directors  0.237611
# 4        shall  0.181880
#
#  Doc 19 top 5 terms:
#       term     score
# 0    state  0.275345
# 1  colored  0.167865
# 2     ohio  0.138874
# 3    black  0.138656
# 4  mulatto  0.134529
#
#  Doc 20 top 5 terms:
#          term     score
# 0    langston  0.414170
# 1  convention  0.256383
# 2      county  0.180967
# 3          mr  0.179712
# 4   committee  0.162316
#
#  Doc 21 top 5 terms:
#         term     score
# 0     people  0.177149
# 1      shall  0.171204
# 2    colored  0.152831
# 3  committee  0.148606
# 4         mr  0.135410
#
#  Doc 22 top 5 terms:
#          term     score
# 0  conference  0.323474
# 1     colored  0.249002
# 2    appendix  0.194914
# 3      people  0.168993
# 4   migration  0.161156
#
#  Doc 23 top 5 terms:
#          term     score
# 0     parsons  0.445155
# 1       avery  0.224804
# 2  convention  0.207347
# 3   fulbright  0.170118
# 4      kansas  0.144403
#
#  Doc 24 top 5 terms:
#            term     score
# 0        people  0.272371
# 1          ohio  0.207459
# 2  deprivations  0.165056
# 3         state  0.156696
# 4      petition  0.144426
#
#  Doc 25 top 5 terms:
#          term     score
# 0      garnit  0.263450
# 1   committee  0.210695
# 2  convention  0.197220
# 3  resolution  0.181191
# 4      people  0.155787
#
#  Doc 26 top 5 terms:
#        term     score
# 0   britton  0.443921
# 1   meeting  0.235764
# 2    graham  0.229352
# 3     haute  0.208095
# 4  overalls  0.208095
#
#  Doc 27 top 5 terms:
#             term     score
# 0         conway  0.397038
# 1  conservatives  0.189969
# 2     convention  0.187194
# 3        orleans  0.174600
# 4            men  0.142113
#
#  Doc 28 top 5 terms:
#          term     score
# 0      county  0.321024
# 1  conference  0.307840
# 2    district  0.277439
# 3       scott  0.192578
# 4       smith  0.158536
#
#  Doc 29 top 5 terms:
#            term     score
# 0  indianapolis  0.271755
# 1        rights  0.169428
# 2         state  0.157253
# 3      founders  0.153660
# 4        secure  0.144245
#
#  Doc 30 top 5 terms:
#           term     score
# 0       trades  0.217134
# 1   carpenters  0.200821
# 2  dressmakers  0.198552
# 3    committee  0.181590
# 4   convention  0.154882
#
#  Doc 31 top 5 terms:
#         term     score
# 0    council  0.690496
# 1     morrel  0.258533
# 2    duffins  0.189591
# 3  mcdonough  0.175098
# 4       york  0.150406
#
#  Doc 32 top 5 terms:
#            term     score
# 0   mississippi  0.402594
# 1       masters  0.191003
# 2        sudden  0.188775
# 3      freedmen  0.181959
# 4  expatriation  0.170507
#
#  Doc 33 top 5 terms:
#      term     score
# 0     mob  0.412378
# 1    klux  0.362147
# 2      ku  0.362147
# 3  county  0.309051
# 4    1870  0.298552
#
#  Doc 34 top 5 terms:
#         term     score
# 0      astor  0.231715
# 1    jenkins  0.137870
# 2   citizens  0.130966
# 3        fur  0.128401
# 4  palladium  0.116205
#
#  Doc 35 top 5 terms:
#         term     score
# 0         mr  0.473643
# 1      newby  0.258770
# 2  committee  0.216769
# 3   townsend  0.193650
# 4     mirror  0.177392
#
#  Doc 36 top 5 terms:
#       term     score
# 0  colored  0.272621
# 1      men  0.225615
# 2     ohio  0.204352
# 3   states  0.177469
# 4   rights  0.143913
#
#  Doc 37 top 5 terms:
#          term     score
# 0      voters  0.350159
# 1     colored  0.325907
# 2      ticket  0.169780
# 3     garnett  0.145666
# 4  convention  0.138778
#
#  Doc 38 top 5 terms:
#          term     score
# 0      cheers  0.202390
# 1       state  0.180034
# 2  convention  0.178821
# 3       scars  0.132188
# 4         men  0.129585
#
#  Doc 39 top 5 terms:
#          term     score
# 0     sailors  0.324393
# 1    soldiers  0.181491
# 2  convention  0.176602
# 3      nation  0.156867
# 4    langston  0.138365
#
#  Doc 40 top 5 terms:
#          term     score
# 0      bonner  0.216398
# 1        byrd  0.216398
# 2    robinson  0.204417
# 3  convention  0.197245
# 4     barguet  0.176601
#
#  Doc 41 top 5 terms:
#            term     score
# 0  poughkeepsie  0.288840
# 1       colored  0.188486
# 2           men  0.167128
# 3         human  0.133009
# 4      resolved  0.119736
#
#  Doc 42 top 5 terms:
#           term     score
# 0         hond  0.554320
# 1  mississippi  0.423475
# 2       league  0.252251
# 3        foote  0.240940
# 4    vicksburg  0.188080
#
#  Doc 43 top 5 terms:
#         term     score
# 0     tibbet  0.498725
# 1       cris  0.398980
# 2    johnson  0.215952
# 3  armstrong  0.198151
# 4      baker  0.181921
#
#  Doc 44 top 5 terms:
#       term     score
# 0   people  0.334914
# 1   exodus  0.264275
# 2  colored  0.200725
# 3    south  0.186865
# 4    texas  0.174920
#
#  Doc 45 top 5 terms:
#            term     score
# 0       colored  0.225487
# 1    convention  0.172772
# 2           new  0.157286
# 3            mr  0.144315
# 4  civilization  0.137056
#
#  Doc 46 top 5 terms:
#           term     score
# 0   middletown  0.488504
# 1     students  0.213983
# 2  connecticut  0.198057
# 3        beman  0.164529
# 4         1854  0.150651
#
#  Doc 47 top 5 terms:
#          term     score
# 0  temperance  0.255291
# 1  convention  0.184088
# 2    crummill  0.160128
# 3         rev  0.159193
# 4      jersey  0.157800
#
#  Doc 48 top 5 terms:
#           term     score
# 0          sec  0.376419
# 1        state  0.232410
# 2  connecticut  0.183809
# 3         blot  0.170220
# 4       people  0.153896
#
#  Doc 49 top 5 terms:
#          term     score
# 0     liberia  0.307288
# 1   baltimore  0.204430
# 2      africa  0.159628
# 3  dorchester  0.153036
# 4      people  0.144247
#  Doc 50 top 5 terms:
#       term     score
# 0   ruffin  0.240711
# 1  downing  0.229288
# 2       mr  0.227927
# 3  colored  0.216491
# 4   grimes  0.195428
#
#  Doc 51 top 5 terms:
#            term     score
# 0       comrade  0.580778
# 1       sailors  0.249652
# 2  pennsylvania  0.235096
# 3      soldiers  0.201752
# 4      underdue  0.193593
#
#  Doc 52 top 5 terms:
#         term     score
# 0  tennessee  0.356774
# 1    colored  0.227636
# 2     rights  0.210291
# 3   citizens  0.169796
# 4      civil  0.153688
#
#  Doc 53 top 5 terms:
#         term     score
# 0     advise  0.386822
# 1   maryland  0.290741
# 2   exertion  0.170982
# 3  dependent  0.170982
# 4       1866  0.161154
#
#  Doc 54 top 5 terms:
#          term     score
# 0          mr  0.255193
# 1  convention  0.174814
# 2         men  0.168010
# 3      league  0.160567
# 4       shall  0.146885
#
#  Doc 55 top 5 terms:
#           term     score
# 0  leavenworth  0.222077
# 1        right  0.185493
# 2        state  0.175548
# 3        class  0.155554
# 4     equality  0.151689
#
#  Doc 56 top 5 terms:
#       term     score
# 0   league  0.311034
# 1       mr  0.182123
# 2  jenkins  0.178367
# 3   county  0.175116
# 4     ohio  0.174551
#
#  Doc 57 top 5 terms:
#        term     score
# 0  suffrage  0.163170
# 1  resolved  0.153458
# 2  citizens  0.151171
# 3   colored  0.147530
# 4      1845  0.146533
#
#  Doc 58 top 5 terms:
#         term     score
# 0     league  0.596575
# 1         mr  0.234727
# 2   national  0.181128
# 3  committee  0.153023
# 4      equal  0.145337
#
#  Doc 59 top 5 terms:
#         term     score
# 0     league  0.405638
# 1         50  0.216227
# 2     rights  0.136184
# 3        men  0.112907
# 4  oppressor  0.110271
#
#  Doc 60 top 5 terms:
#       term     score
# 0    gould  0.369898
# 1   league  0.352194
# 2  trenton  0.257448
# 3   motion  0.230589
# 4   turpin  0.188306
#
#  Doc 61 top 5 terms:
#         term     score
# 0  committee  0.249589
# 1     canada  0.203525
# 2      shall  0.186284
# 3    colored  0.167832
# 4       bibb  0.167539
#
#  Doc 62 top 5 terms:
#         term     score
# 0       60th  0.390671
# 1       iowa  0.379205
# 2       inft  0.279051
# 3   soldiers  0.178962
# 4  muscatine  0.169809
#
#  Doc 63 top 5 terms:
#          term     score
# 0     greenly  0.308384
# 1  convention  0.297678
# 2  fitzgerald  0.283658
# 3      motion  0.247647
# 4    resolved  0.240463
#
#  Doc 64 top 5 terms:
#          term     score
# 0          mr  0.425678
# 1   pinchback  0.315519
# 2  convention  0.263991
# 3     colored  0.176891
# 4      rights  0.153556
#
#  Doc 65 top 5 terms:
#         term     score
# 0    roberts  0.220244
# 1  westbrook  0.213242
# 2       kerr  0.213242
# 3    gillett  0.213242
# 4    blocker  0.213242
#
#  Doc 66 top 5 terms:
#          term     score
# 0      people  0.232969
# 1     colored  0.212764
# 2  convention  0.207084
# 3    carolina  0.164458
# 4     greeley  0.131845
#
#  Doc 67 top 5 terms:
#            term     score
# 0  philadelphia  0.230580
# 1       tickets  0.221846
# 2         catto  0.202315
# 3        league  0.198258
# 4     exceeding  0.176578
#
#  Doc 68 top 5 terms:
#        term     score
# 0    league  0.403496
# 1    adrian  0.350956
# 2   detroit  0.337116
# 3        mr  0.270139
# 4  michigan  0.165724
#
#  Doc 69 top 5 terms:
#       term     score
# 0    negro  0.245858
# 1   tenant  0.155941
# 2  hampton  0.152417
# 3     work  0.150071
# 4  colored  0.149676
#
#  Doc 70 top 5 terms:
#             term     score
# 0        colored  0.321845
# 1       plodding  0.267719
# 2  officeholders  0.267719
# 3          trade  0.258754
# 4       maryland  0.249429
#
#  Doc 71 top 5 terms:
#          term     score
# 0     curious  0.213163
# 1  convention  0.183503
# 2       shown  0.168258
# 3       ninth  0.152137
# 4     colored  0.134668
#
#  Doc 72 top 5 terms:
#            term     score
# 0    harrisburg  0.293851
# 1  philadelphia  0.293040
# 2        league  0.251963
# 3            mr  0.247899
# 4         welch  0.184562
#
#  Doc 73 top 5 terms:
#          term     score
# 0      league  0.278365
# 1      conrad  0.265883
# 2  cincinnati  0.216300
# 3        ohio  0.212010
# 4          mr  0.184338
#
#  Doc 74 top 5 terms:
#          term     score
# 0       state  0.234995
# 1   committee  0.227805
# 2      people  0.203205
# 3    resolved  0.184886
# 4  convention  0.170253
#
#  Doc 75 top 5 terms:
#          term     score
# 0  convention  0.275043
# 1     colored  0.211940
# 2      people  0.189092
# 3          mr  0.170008
# 4      harris  0.150206
#
#  Doc 76 top 5 terms:
#          term     score
# 0       state  0.309025
# 1      people  0.247259
# 2     colored  0.201481
# 3  population  0.190495
# 4     suffers  0.144672
#
#  Doc 77 top 5 terms:
#          term     score
# 0  convention  0.264676
# 1     colored  0.201759
# 2      people  0.187835
# 3          mr  0.168877
# 4      harris  0.149207
#
#  Doc 78 top 5 terms:
#          term     score
# 0          mr  0.261726
# 1      colour  0.230220
# 2  convention  0.218329
# 3    coloured  0.202376
# 4       shall  0.174183
#
#  Doc 79 top 5 terms:
#          term     score
# 0       slave  0.193675
# 1        1855  0.180260
# 2       state  0.157096
# 3       south  0.149644
# 4  williamson  0.137202
#
#  Doc 80 top 5 terms:
#         term     score
# 0     status  0.272572
# 1      negro  0.247316
# 2      party  0.207960
# 3    negroes  0.186818
# 4  political  0.165438
#
#  Doc 81 top 5 terms:
#       term     score
# 0   people  0.237009
# 1    dover  0.220255
# 2    state  0.190894
# 3  colored  0.180893
# 4   coppin  0.173620
#
#  Doc 82 top 5 terms:
#        term     score
# 0      john  0.263562
# 1  langston  0.249311
# 2       mrs  0.215335
# 3   society  0.182048
# 4      miss  0.166207
#
#  Doc 83 top 5 terms:
#       term     score
# 0  colored  0.247655
# 1   remond  0.187850
# 2       mr  0.185630
# 3   henson  0.174202
# 4     dred  0.159686
#
#  Doc 84 top 5 terms:
#          term     score
# 0       state  0.207463
# 1      people  0.149689
# 2   committee  0.148705
# 3    illinois  0.138995
# 4  convention  0.134137
#
#  Doc 85 top 5 terms:
#          term     score
# 0     delarge  0.316483
# 1     ransier  0.243575
# 2  charleston  0.217290
# 3    poinsett  0.197802
# 4          mr  0.184387
#
#  Doc 86 top 5 terms:
#       term     score
# 0     cuba  0.551127
# 1  spanish  0.354715
# 2    cuban  0.303374
# 3    spain  0.256094
# 4  slavery  0.206215
#
#  Doc 87 top 5 terms:
#          term     score
# 0      league  0.520557
# 1       haven  0.280424
# 2       shall  0.235117
# 3         sec  0.216524
# 4  convention  0.202425
#
#  Doc 88 top 5 terms:
#          term     score
# 0  convention  0.238842
# 1    langston  0.196978
# 2        prof  0.176593
# 3          ex  0.124603
# 4         sir  0.121564
#
#  Doc 89 top 5 terms:
#          term     score
# 0    resolved  0.250473
# 1    marshals  0.203989
# 2  abstinence  0.169088
# 3       drive  0.156434
# 4      prison  0.134187
#
#  Doc 90 top 5 terms:
#            term     score
# 0    convention  0.323820
# 1  commonwealth  0.196240
# 2        vashon  0.182039
# 3       woodson  0.178025
# 4         lewis  0.160318
#
#  Doc 91 top 5 terms:
#       term     score
# 0   states  0.333971
# 1  colored  0.243691
# 2      men  0.238823
# 3  awarded  0.189129
# 4   nation  0.147846
#
#  Doc 92 top 5 terms:
#          term     score
# 0       shall  0.276723
# 1  convention  0.254964
# 2      league  0.243835
# 3        hara  0.188048
# 4     raleigh  0.179154
#
#  Doc 93 top 5 terms:
#         term     score
# 0  tennessee  0.338679
# 1       fisk  0.227494
# 2   davidson  0.179601
# 3       1865  0.155204
# 4  committee  0.144917
#
#  Doc 94 top 5 terms:
#          term     score
# 0  government  0.159997
# 1         law  0.148082
# 2        bare  0.134149
# 3    equality  0.125209
# 4      denial  0.110049
#
#  Doc 95 top 5 terms:
#         term     score
# 0      state  0.233788
# 1   langston  0.194522
# 2     county  0.174989
# 3    jenkins  0.167097
# 4  committee  0.146333
#
#  Doc 96 top 5 terms:
#        term     score
# 0   colored  0.215947
# 1    county  0.171839
# 2    people  0.153792
# 3      1852  0.151824
# 4  resolved  0.138678
#
#  Doc 97 top 5 terms:
#        term     score
# 0   colored  0.261345
# 1    people  0.248838
# 2      race  0.180805
# 3     texas  0.178236
# 4  governor  0.171776
#
#  Doc 98 top 5 terms:
#       term     score
# 0   county  0.293606
# 1  colored  0.211483
# 2   kuklux  0.200411
# 3    state  0.157393
# 4    wages  0.151212
#
#  Doc 99 top 5 terms:
#          term     score
# 0  convention  0.317817
# 1     indiana  0.311940
# 2         rev  0.293160
# 3     greenly  0.215019
# 4   americans  0.176298
#
#  Doc 100 top 5 terms:
#       term     score
# 0   people  0.192481
# 1      men  0.187878
# 2    color  0.165065
# 3  colored  0.161437
# 4    labor  0.126984
#
#  Doc 101 top 5 terms:
#          term     score
# 0        capt  0.247274
# 1  convention  0.236527
# 2          mr  0.214674
# 3    ingraham  0.200197
# 4   committee  0.177413
#  Doc 102 top 5 terms:
#          term     score
# 0      watson  0.277596
# 1  convention  0.263644
# 2          mr  0.229749
# 3    langston  0.191887
# 4  resolution  0.176484
#
#  Doc 103 top 5 terms:
#          term     score
# 0  resolution  0.257054
# 1  convention  0.241276
# 2    resolved  0.174905
# 3     colored  0.164048
# 4   cleveland  0.157531
#
#  Doc 104 top 5 terms:
#       term     score
# 0    taney  0.228246
# 1  watkins  0.189194
# 2     dred  0.178406
# 3   garnet  0.175036
# 4    party  0.163027
#
#  Doc 105 top 5 terms:
#          term     score
# 0        kagi  0.404292
# 1          mr  0.311896
# 2     whipple  0.281167
# 3      delany  0.245791
# 4  convention  0.244412
#
#  Doc 106 top 5 terms:
#          term     score
# 0  centennial  0.235067
# 1          mr  0.230670
# 2  convention  0.210930
# 3     colored  0.204213
# 4   pinchback  0.198903
#
#  Doc 107 top 5 terms:
#        term     score
# 0  hamburgh  0.431631
# 1    butler  0.284860
# 2   company  0.255909
# 3    rivers  0.255355
# 4     drill  0.196196
#
#  Doc 108 top 5 terms:
#          term     score
# 0   committee  0.212417
# 1          mr  0.209526
# 2         san  0.166425
# 3  convention  0.157382
# 4  sacramento  0.154064
#
#  Doc 109 top 5 terms:
#          term     score
# 0       labor  0.411569
# 1  convention  0.155467
# 2     colored  0.149171
# 3      bureau  0.143277
# 4    national  0.117539
#
#  Doc 110 top 5 terms:
#          term     score
# 0    langston  0.252172
# 1  resolution  0.207516
# 2  convention  0.188033
# 3     colored  0.172305
# 4       yancy  0.168029
#
#  Doc 111 top 5 terms:
#          term     score
# 0       state  0.229618
# 1   committee  0.199647
# 2      people  0.194810
# 3    resolved  0.174237
# 4  convention  0.163925
#
#  Doc 112 top 5 terms:
#          term     score
# 0  convention  0.261215
# 1    seconded  0.250224
# 2     paschal  0.226639
# 3      coxsin  0.184049
# 4          mr  0.167623
#
#  Doc 113 top 5 terms:
#             term     score
# 0           hunt  0.306729
# 1           york  0.261720
# 2  appropriation  0.214595
# 3           1852  0.210385
# 4   colonization  0.204066
#
#  Doc 114 top 5 terms:
#            term     score
# 0         shall  0.295224
# 1        colour  0.275164
# 2      managers  0.251453
# 3       society  0.236446
# 4  philadelphia  0.160955
#
#  Doc 115 top 5 terms:
#           term     score
# 0        beman  0.308156
# 1        haven  0.175601
# 2  connecticut  0.170553
# 3    africanus  0.159137
# 4        state  0.158741
#
#  Doc 116 top 5 terms:
#           term     score
# 0        texas  0.253592
# 1        state  0.190104
# 2  acquisition  0.183954
# 3       fellow  0.151503
# 4        cuney  0.143944
#
#  Doc 117 top 5 terms:
#            term     score
# 0    convention  0.311718
# 1        colour  0.246521
# 2         shall  0.164574
# 3  philadelphia  0.163427
# 4      jennings  0.147988
#
#  Doc 118 top 5 terms:
#         term     score
# 0     henson  0.278190
# 1     canada  0.254821
# 2         mr  0.251583
# 3  smallwood  0.240978
# 4      liles  0.218419
#
#  Doc 119 top 5 terms:
#         term     score
# 0  minnesota  0.227015
# 1      great  0.182754
# 2      shall  0.179013
# 3     cheers  0.177666
# 4    colored  0.171545
#
#  Doc 120 top 5 terms:
#        term     score
# 0    county  0.467551
# 1   murders  0.437669
# 2  outrages  0.214012
# 3   chinese  0.197513
# 4   arrests  0.176401
#
#  Doc 121 top 5 terms:
#         term     score
# 0      bayne  0.497907
# 1         dr  0.213493
# 2        cox  0.171663
# 3     norton  0.156222
# 4  committee  0.144736
#
#  Doc 122 top 5 terms:
#          term     score
# 0  convention  0.242487
# 1      county  0.225465
# 2       louis  0.221933
# 3      rector  0.211844
# 4     dickson  0.211055
#
#  Doc 123 top 5 terms:
#          term     score
# 0    mcintyre  0.247741
# 1  resolution  0.212295
# 2          mr  0.203823
# 3  convention  0.170433
# 4        seth  0.166692
#
#  Doc 124 top 5 terms:
#            term     score
# 0         party  0.174087
# 1     hartranft  0.159549
# 2    republican  0.153541
# 3          ages  0.148649
# 4  presidential  0.144359
#
#  Doc 125 top 5 terms:
#       term     score
# 0  chaplin  0.440661
# 1  slavery  0.280362
# 2   slaves  0.128010
# 3      man  0.126859
# 4    slave  0.121115
#
#  Doc 126 top 5 terms:
#           term     score
# 0         come  0.181186
# 1   enterprize  0.169019
# 2    influence  0.167138
# 3     brethren  0.146878
# 4  occupations  0.146533
#
#  Doc 127 top 5 terms:
#           term     score
# 0           mr  0.272793
# 1        dupee  0.254238
# 2  association  0.236415
# 3    committee  0.170234
# 4       straws  0.167635
#
#  Doc 128 top 5 terms:
#          term     score
# 0  convention  0.235984
# 1    langston  0.227764
# 2  resolution  0.195965
# 3     society  0.171802
# 4   committee  0.154758
#
#  Doc 129 top 5 terms:
#        term     score
# 0     civil  0.170629
# 1  american  0.150913
# 2   liberty  0.129379
# 3  congress  0.115136
# 4    rights  0.113647
#
#  Doc 130 top 5 terms:
#          term     score
# 0  shrewsbury  0.267697
# 1      miller  0.196844
# 2      sawyer  0.162771
# 3    mckinlay  0.153969
# 4    district  0.135367
#
#  Doc 131 top 5 terms:
#      term     score
# 0   voted  0.272392
# 1   beard  0.269431
# 2   finch  0.244684
# 3    bibb  0.232225
# 4  deputy  0.211812
#
#  Doc 132 top 5 terms:
#          term     score
# 0      colour  0.238383
# 1  convention  0.236836
# 2    seconded  0.216146
# 3   committee  0.166594
# 4     sipkins  0.157756
#
#  Doc 133 top 5 terms:
#         term     score
# 0    council  0.443950
# 1   ringgold  0.261610
# 2       nell  0.235106
# 3  sanderson  0.231874
# 4     grimes  0.208581
#
#  Doc 134 top 5 terms:
#          term     score
# 0          va  0.372337
# 1  alexandria  0.290934
# 2     beckley  0.194883
# 3  convention  0.173747
# 4         rev  0.160531
#
#  Doc 135 top 5 terms:
#           term     score
# 0       kansas  0.417502
# 1        twine  0.170955
# 2  leavenworth  0.160915
# 3       menser  0.158662
# 4        black  0.144946
#
#  Doc 136 top 5 terms:
#       term     score
# 0   normal  0.344260
# 1   school  0.202574
# 2    weeks  0.188060
# 3  simmons  0.176484
# 4    state  0.175790
#
#  Doc 137 top 5 terms:
#       term     score
# 0    locke  0.259707
# 1  trenton  0.222628
# 2   camden  0.207707
# 3  woodlin  0.203713
# 4    shall  0.191086
#
#  Doc 138 top 5 terms:
#            term     score
# 0  pennsylvania  0.143753
# 1         shall  0.131627
# 2        county  0.125725
# 3    convention  0.119621
# 4          bias  0.119230
#
#  Doc 139 top 5 terms:
#             term     score
# 0  commissioners  0.206345
# 1            000  0.181769
# 2         people  0.179153
# 3          board  0.176505
# 4          shall  0.156495
#
#  Doc 140 top 5 terms:
#           term     score
# 0     kentucky  0.588562
# 1    frankfort  0.372078
# 2  association  0.235456
# 3          sec  0.154968
# 4        shall  0.134914
#
#  Doc 141 top 5 terms:
#        term     score
# 0  seconded  0.311462
# 1   whipper  0.228774
# 2        mr  0.201714
# 3    motion  0.199957
# 4  resolved  0.198941
#
#  Doc 142 top 5 terms:
#          term     score
# 0     toronto  0.367936
# 1  convention  0.273411
# 2      fisher  0.215410
# 3   committee  0.177852
# 4      scoble  0.171015
#
#  Doc 143 top 5 terms:
#          term     score
# 0  convention  0.202734
# 1        date  0.192533
# 2       state  0.185554
# 3  binghamton  0.174567
# 4  canvassers  0.164315
#
#  Doc 144 top 5 terms:
#        term     score
# 0  galloway  0.429499
# 1   raleigh  0.343898
# 2       sir  0.216141
# 3        mr  0.212542
# 4     negro  0.204302
#
#  Doc 145 top 5 terms:
#          term     score
# 0   committee  0.228595
# 1  rensselaer  0.228011
# 2         van  0.192954
# 3      report  0.192267
# 4       beman  0.189467
#
#  Doc 146 top 5 terms:
#           term     score
# 0  association  0.481843
# 1        shall  0.293856
# 2      council  0.230666
# 3     georgian  0.219508
# 4    president  0.201745

# %% [markdown]
# ## Sorting Chunks of Documents ##
#
# You can also sort *chunks* of documents by socre. [Here is an example of this from 538](https://fivethirtyeight.com/features/these-are-the-phrases-each-gop-candidate-repeats-most/)
#
# Note that their TF-IDF scores seem wildly different than ours. That's because they haven't normalized their scores. Again, it's not the raw number that matters but the ranking that the scores enable.

# %% [markdown]
# ## Cosine Similarity ##
#
# Another thing you can do is calculate the cosine similarity between documents. We'll talk more about this in the future, but here's a quick example:

# %%
# CALCULATE SIMILARITY TO FIRST DOC 

from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(tfidf_vectorizer_vectors[0:1], tfidf_vectorizer_vectors)
# Out:
# array([[1.        , 0.06465099, 0.05610237, 0.04711738, 0.06962622,
#         0.09625273, 0.08169905, 0.07551052, 0.05405891, 0.10062727,
#         0.07003329, 0.07941162, 0.08219579, 0.09451411, 0.04486977,
#         0.02077095, 0.02486525, 0.04318454, 0.03951665, 0.10057563,
#         0.07303898, 0.14159949, 0.13675211, 0.08527692, 0.07197963,
#         0.10856095, 0.03973465, 0.07398188, 0.04941485, 0.0436834 ,
#         0.07951614, 0.04175132, 0.03781364, 0.01266459, 0.09214135,
#         0.06510835, 0.08726553, 0.05812651, 0.09211778, 0.055983  ,
#         0.07041372, 0.08540176, 0.00807353, 0.01479589, 0.10073539,
#         0.1284685 , 0.05295548, 0.07301611, 0.06173464, 0.08242942,
#         0.07501834, 0.04647728, 0.08177462, 0.04023591, 0.13104857,
#         0.09392625, 0.05611693, 0.10734953, 0.06743812, 0.06938436,
#         0.06165032, 0.07661391, 0.06796959, 0.05065519, 0.09440454,
#         0.01808766, 0.08056023, 0.02029955, 0.05239651, 0.10815004,
#         0.02802066, 0.04574778, 0.009497  , 0.01671147, 0.11348194,
#         0.08233534, 0.11400599, 0.0811382 , 0.08470993, 0.09905004,
#         0.13740265, 0.08259536, 0.0503753 , 0.1003354 , 0.12448169,
#         0.07203219, 0.05686247, 0.07619141, 0.08266644, 0.05094517,
#         0.0745017 , 0.08713999, 0.0888496 , 0.09598201, 0.03947623,
#         0.08385591, 0.11960157, 0.08922629, 0.08035656, 0.05454557,
#         0.13389315, 0.05375393, 0.08747542, 0.11095886, 0.06969367,
#         0.01986267, 0.11241955, 0.04312598, 0.09878897, 0.09974567,
#         0.09551878, 0.1153796 , 0.07927057, 0.07248396, 0.05562233,
#         0.09252944, 0.06520073, 0.08583652, 0.04169185, 0.11505102,
#         0.03218829, 0.06641979, 0.06353188, 0.11200487, 0.04492648,
#         0.09185681, 0.03209571, 0.05650371, 0.0454016 , 0.07199536,
#         0.04182214, 0.0390336 , 0.08499309, 0.0349119 , 0.08760138,
#         0.08668144, 0.06385237, 0.078952  , 0.0870744 , 0.12359485,
#         0.04041798, 0.08026182, 0.05908895, 0.063913  , 0.10879654,
#         0.07684251, 0.07187934]])

# %% [markdown]
# ## How to chunk documents by file name ##

# %%
base_dir = "./2019-09-ccp-corpus-0.3/ccprecords/"

war_docs = []

pre_1865 = ""
post_1865 = ""

docs = os.listdir(base_dir) # get a list of all the files in the directory

for doc in docs: # iterate through them
    if not doc.startswith('.'): # get only the .txt files
        with open(base_dir + doc, "r", encoding="utf-8") as file: # force unicode conversion for pcs
            text = file.read() # read in the file as a single text string
            
            # HERE IS WHERE THE CHUNKING HAPPENS
            year = doc[:4] # how you access/slice characters in a string
            
            if int(year) < 1865:
                # DO A THING
            else:
                # DO ANOTHER THING
